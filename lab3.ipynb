# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_moons, make_blobs
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score, silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from itertools import cycle

# %%
centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4, random_state=0)
X = StandardScaler().fit_transform(X)

# %%
plt.scatter(X[:,:1],X[:,1:2])

# %%
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=750)
db = MeanShift(bandwidth=bandwidth).fit(X)

# %%
MeanShift().get_params().keys()
# Out:
# dict_keys(['bandwidth', 'bin_seeding', 'cluster_all', 'max_iter', 'min_bin_freq', 'n_jobs', 'seeds'])

# %%
labels = db.labels_
cluster_centers=db.cluster_centers_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Adjusted Rand Index: %0.3f" % adjusted_rand_score(labels_true, labels))
print(
    "Adjusted Mutual Information: %0.3f"
    % adjusted_mutual_info_score(labels_true, labels)
)
print("Silhouette Coefficient: %0.3f" % silhouette_score(X, labels))
# Out:
# Estimated number of clusters: 3
# Adjusted Rand Index: 0.968
# Adjusted Mutual Information: 0.945
# Silhouette Coefficient: 0.650

# %%
plt.figure(1)
plt.clf()

colors = cycle("bgrcmykbgrcmykbgrcmykbgrcmyk")
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + ".")
    plt.plot(
        cluster_center[0],
        cluster_center[1],
        "o",
        markerfacecolor=col,
        markeredgecolor="k",
        markersize=14,
    )
plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()

# %%
X,labels_true=make_moons(n_samples=1000)
X = StandardScaler().fit_transform(X)
X
# Out:
# array([[-1.17477487,  1.22591281],
#        [ 0.40435149,  0.55918042],
#        [ 0.10121267, -1.33873559],
#        ...,
#        [-0.55880427,  1.51861589],
#        [-0.57584535,  0.4170683 ],
#        [-1.53465528,  0.62346102]])

# %%
plt.scatter(X[:,:1],X[:,1:2])

# %%
bandwidth = estimate_bandwidth(X, quantile=0.1, n_samples=1000)
db = MeanShift(bandwidth =bandwidth, bin_seeding=True).fit(X)

# %%
labels = db.labels_
cluster_centers=db.cluster_centers_

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Adjusted Rand Index: %0.3f" % adjusted_rand_score(labels_true, labels))
print(
    "Adjusted Mutual Information: %0.3f"
    % adjusted_mutual_info_score(labels_true, labels)
)
print("Silhouette Coefficient: %0.3f" % silhouette_score(X, labels))
# Out:
# Estimated number of clusters: 2
# Adjusted Rand Index: 0.592
# Adjusted Mutual Information: 0.485
# Silhouette Coefficient: 0.497

# %%
plt.figure(1)
plt.clf()

colors = cycle("bgrcmykbgrcmykbgrcmykbgrcmyk")
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + ".")
    plt.plot(
        cluster_center[0],
        cluster_center[1],
        "o",
        markerfacecolor=col,
        markeredgecolor="k",
        markersize=14,
    )
plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()

# %% [markdown]
# Alternative models

# %%
centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4, random_state=0)
X = StandardScaler().fit_transform(X)

# %%
plt.scatter(X[:,:1],X[:,1:2])

# %%
bandwidth = estimate_bandwidth(X, quantile=0.1, n_samples=750)
db = MeanShift(bandwidth=bandwidth).fit(X)

# %%
MeanShift().get_params().keys()
# Out:
# dict_keys(['bandwidth', 'bin_seeding', 'cluster_all', 'max_iter', 'min_bin_freq', 'n_jobs', 'seeds'])

# %%
labels = db.labels_
cluster_centers=db.cluster_centers_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Adjusted Rand Index: %0.3f" % adjusted_rand_score(labels_true, labels))
print(
    "Adjusted Mutual Information: %0.3f"
    % adjusted_mutual_info_score(labels_true, labels)
)
print("Silhouette Coefficient: %0.3f" % silhouette_score(X, labels))
# Out:
# Estimated number of clusters: 4
# Adjusted Rand Index: 0.951
# Adjusted Mutual Information: 0.920
# Silhouette Coefficient: 0.548

# %%
plt.figure(1)
plt.clf()

colors = cycle("bgrcmykbgrcmykbgrcmykbgrcmyk")
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + ".")
    plt.plot(
        cluster_center[0],
        cluster_center[1],
        "o",
        markerfacecolor=col,
        markeredgecolor="k",
        markersize=14,
    )
plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()

# %%
X,labels_true=make_moons(n_samples=1000)
X = StandardScaler().fit_transform(X)
X
# Out:
# array([[ 1.44143664, -0.83516883],
#        [-1.49225686,  0.72696915],
#        [ 1.70608229,  0.08856165],
#        ...,
#        [ 1.16229986, -1.23898567],
#        [ 1.72265136,  0.26461758],
#        [-0.63868789,  1.51596764]])

# %%
plt.scatter(X[:,:1],X[:,1:2])

# %%
bandwidth = estimate_bandwidth(X, quantile=0.08, n_samples=1000)
db = MeanShift(bandwidth =bandwidth, bin_seeding=True).fit(X)

# %%
labels = db.labels_
cluster_centers=db.cluster_centers_

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Adjusted Rand Index: %0.3f" % adjusted_rand_score(labels_true, labels))
print(
    "Adjusted Mutual Information: %0.3f"
    % adjusted_mutual_info_score(labels_true, labels)
)
print("Silhouette Coefficient: %0.3f" % silhouette_score(X, labels))
# Out:
# Estimated number of clusters: 6
# Adjusted Rand Index: 0.375
# Adjusted Mutual Information: 0.571
# Silhouette Coefficient: 0.508

# %%
plt.figure(1)
plt.clf()

colors = cycle("bgrcmykbgrcmykbgrcmykbgrcmyk")
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + ".")
    plt.plot(
        cluster_center[0],
        cluster_center[1],
        "o",
        markerfacecolor=col,
        markeredgecolor="k",
        markersize=14,
    )
plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()
